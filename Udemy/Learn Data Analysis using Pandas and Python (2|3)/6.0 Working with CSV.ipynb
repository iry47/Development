# %%
import pandas as pd
data = pd.read_csv('/Users/ryanheadley/Documents/GitHub/Development/Udemy/Learn Data Analysis using Pandas and Python (2|3)/ressources/_occupancyrates.csv')
data.head()
# Out:
#       Time  Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# 0  1999M01                            43.7                             49.0
# 1  1999M02                            41.0                             64.0
# 2  1999M03                            36.5                             58.1
# 3  1999M04                            32.8                             51.2
# 4  1999M05                            24.5                             42.7
#
#    Motels Occupancy rate (percent)  Backpackers Occupancy rate (percent)  \
# 0                             58.1                                  55.6
# 1                             63.8                                  59.3
# 2                             60.1                                  53.8
# 3                             53.9                                  45.8
# 4                             39.4                                  32.5
#
#    Holiday Parks Occupancy rate (percent)
# ...

# %%
data.shift(1)
# Out:
#         Time  Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# 0        NaN                             NaN                              NaN
# 1    1999M01                            43.7                             49.0
# 2    1999M02                            41.0                             64.0
# 3    1999M03                            36.5                             58.1
# 4    1999M04                            32.8                             51.2
# ..       ...                             ...                              ...
# 161  2012M05                            29.0                             49.2
# 162  2012M06                            27.7                             48.0
# 163  2012M07                            29.9                             50.8
# 164  2012M08                            29.3                             53.5
# 165  2012M09                            31.2                             52.3
#
# ...

# %%
data.head()
# Out:
#       Time  Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# 0  1999M01                            43.7                             49.0
# 1  1999M02                            41.0                             64.0
# 2  1999M03                            36.5                             58.1
# 3  1999M04                            32.8                             51.2
# 4  1999M05                            24.5                             42.7
#
#    Motels Occupancy rate (percent)  Backpackers Occupancy rate (percent)  \
# 0                             58.1                                  55.6
# 1                             63.8                                  59.3
# 2                             60.1                                  53.8
# 3                             53.9                                  45.8
# 4                             39.4                                  32.5
#
#    Holiday Parks Occupancy rate (percent)
# ...

# %%
data = pd.read_csv('/Users/ryanheadley/Documents/GitHub/Development/Udemy/Learn Data Analysis using Pandas and Python (2|3)/ressources/_occupancyrates.csv',index_col="Time")
data.head()
# Out:
#          Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# Time
# 1999M01                            43.7                             49.0
# 1999M02                            41.0                             64.0
# 1999M03                            36.5                             58.1
# 1999M04                            32.8                             51.2
# 1999M05                            24.5                             42.7
#
#          Motels Occupancy rate (percent)  \
# Time
# 1999M01                             58.1
# 1999M02                             63.8
# 1999M03                             60.1
# 1999M04                             53.9
# 1999M05                             39.4
#
#          Backpackers Occupancy rate (percent)  \
# Time
# 1999M01                                  55.6
# 1999M02                                  59.3
# 1999M03                                  53.8
# 1999M04                                  45.8
# ...

# %%
data.shift(1).head()
# Out:
#          Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# Time
# 1999M01                             NaN                              NaN
# 1999M02                            43.7                             49.0
# 1999M03                            41.0                             64.0
# 1999M04                            36.5                             58.1
# 1999M05                            32.8                             51.2
#
#          Motels Occupancy rate (percent)  \
# Time
# 1999M01                              NaN
# 1999M02                             58.1
# 1999M03                             63.8
# 1999M04                             60.1
# 1999M05                             53.9
#
#          Backpackers Occupancy rate (percent)  \
# Time
# 1999M01                                   NaN
# 1999M02                                  55.6
# 1999M03                                  59.3
# 1999M04                                  53.8
# ...

# %% [markdown]
# #### Every row was shifted to the following time period (the next month)

# %%
data['Previous Total Occupancy'] = data['Total Occupancy rate (percent)'].shift(1)
data.head()
# Out:
#          Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# Time
# 1999M01                            43.7                             49.0
# 1999M02                            41.0                             64.0
# 1999M03                            36.5                             58.1
# 1999M04                            32.8                             51.2
# 1999M05                            24.5                             42.7
#
#          Motels Occupancy rate (percent)  \
# Time
# 1999M01                             58.1
# 1999M02                             63.8
# 1999M03                             60.1
# 1999M04                             53.9
# 1999M05                             39.4
#
#          Backpackers Occupancy rate (percent)  \
# Time
# 1999M01                                  55.6
# 1999M02                                  59.3
# 1999M03                                  53.8
# 1999M04                                  45.8
# ...

# %%
data['Diff in Occupancy from yesterday'] = data['Total Occupancy rate (percent)'] - data['Previous Total Occupancy']
data.head()
# Out:
#          Total Occupancy rate (percent)  Hotels Occupancy rate (percent)  \
# Time
# 1999M01                            43.7                             49.0
# 1999M02                            41.0                             64.0
# 1999M03                            36.5                             58.1
# 1999M04                            32.8                             51.2
# 1999M05                            24.5                             42.7
#
#          Motels Occupancy rate (percent)  \
# Time
# 1999M01                             58.1
# 1999M02                             63.8
# 1999M03                             60.1
# 1999M04                             53.9
# 1999M05                             39.4
#
#          Backpackers Occupancy rate (percent)  \
# Time
# 1999M01                                  55.6
# 1999M02                                  59.3
# 1999M03                                  53.8
# 1999M04                                  45.8
# ...

# %% [markdown]
# #### Write this data to the file

# %%
data.to_csv('/Users/ryanheadley/Documents/GitHub/Development/Udemy/Learn Data Analysis using Pandas and Python (2|3)/ressources/_occupancyrates.csv')
