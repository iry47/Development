# %%
import pandas as pd
data = pd.read_csv('/Users/ryanheadley/Documents/GitHub/Development/Udemy/Learn Data Analysis using Pandas and Python (2|3)/ressources/_forestry.csv')
data.head()
# Out:
#   Quarter  Natural Forests  Plantation Forests
# 0  2000Q1               12                4531
# 1  2000Q2               15                4972
# 2  2000Q3               16                4901
# 3  2000Q4               11                4821
# 4  2001Q1               11                4538

# %%
data.shape
# Out:
# (55, 3)

# %%
data.plot()

# %% [markdown]
# ### Simple JOIN examples

# %%
#inner join
dataframe1 = pd.DataFrame({
    "employee":["ABC","XYZ","MNO"],
    "age": ["25","30","22"]
})
dataframe1
# Out:
#   employee age
# 0      ABC  25
# 1      XYZ  30
# 2      MNO  22

# %%
dataframe2 = pd.DataFrame({
    "employee":["ABC","XYZ","PQR"],
    "salary": ["10000","125000","5000"]
})
dataframe2
# Out:
#   employee  salary
# 0      ABC   10000
# 1      XYZ  125000
# 2      PQR    5000

# %%
pd.merge(dataframe1,dataframe2, on="employee")
# Out:
#   employee age  salary
# 0      ABC  25   10000
# 1      XYZ  30  125000

# %%
#outer join
dataframe3 = pd.merge(dataframe1,dataframe2, on="employee", how="left")
dataframe3
# Out:
#   employee age  salary
# 0      ABC  25   10000
# 1      XYZ  30  125000
# 2      MNO  22     NaN

# %%
#right join
dataframe3 = pd.merge(dataframe1,dataframe2, on="employee", how="right")
dataframe3
# Out:
#   employee  age  salary
# 0      ABC   25   10000
# 1      XYZ   30  125000
# 2      PQR  NaN    5000

# %% [markdown]
# ### Pivoting Tables

# %%
data.head()
# Out:
#   Quarter  Natural Forests  Plantation Forests
# 0  2000Q1               12                4531
# 1  2000Q2               15                4972
# 2  2000Q3               16                4901
# 3  2000Q4               11                4821
# 4  2001Q1               11                4538

# %%
#pivot the data
data.pivot(index="Natural Forests", columns="Quarter")
# Out:
#                 Plantation Forests                                          \
# Quarter                     2000Q1  2000Q2  2000Q3  2000Q4  2001Q1  2001Q2
# Natural Forests
# 1                              NaN     NaN     NaN     NaN     NaN     NaN
# 2                              NaN     NaN     NaN     NaN     NaN     NaN
# 3                              NaN     NaN     NaN     NaN     NaN     NaN
# 4                              NaN     NaN     NaN     NaN     NaN     NaN
# 5                              NaN     NaN     NaN     NaN     NaN     NaN
# 6                              NaN     NaN     NaN     NaN     NaN     NaN
# 7                              NaN     NaN     NaN     NaN     NaN     NaN
# 8                              NaN     NaN     NaN     NaN     NaN     NaN
# 9                              NaN     NaN     NaN     NaN     NaN     NaN
# 10                             NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
data.pivot_table(index="Natural Forests", aggfunc="mean")
# Out:
#                  Plantation Forests
# Natural Forests
# 1                       5344.000000
# 2                       4714.000000
# 3                       6411.800000
# 4                       5908.375000
# 5                       5429.363636
# 6                       5305.500000
# 7                       5779.666667
# 8                       5270.333333
# 9                       5364.500000
# 10                      5602.500000
# 11                      4997.666667
# 12                      4531.000000
# 13                      5385.000000
# 14                      4804.000000
# 15                      5222.000000
# 16                      4901.000000

# %%
data.pivot_table(index="Natural Forests", aggfunc="sum")
# Out:
#                  Plantation Forests
# Natural Forests
# 1                              5344
# 2                              9428
# 3                             32059
# 4                             47267
# 5                             59723
# 6                             42444
# 7                             17339
# 8                             15811
# 9                             10729
# 10                            11205
# 11                            14993
# 12                             4531
# 13                             5385
# 14                             4804
# 15                            15666
# 16                             4901
